# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=10,6
import seaborn as sns
ElecData=pd.read_csv("C:/Users/OVC 2/Desktop/Series_Data.csv")

# %%
ElecData
from datetime import datetime
IElecData=ElecData.set_index(['FullDate'])

# %%
#test_data

# %%
IElecData.head(2757)
IElecDataH=IElecData.head(2757)
IElecDataH
# Out:
#                   Tmax     SysLoad  GasPrice  ElecPrice
# FullDate
# 9/1/2010 0:00     15.8  1688.21500    3.6900     23.710
# 9/1/2010 1:00     15.8  1669.19500    3.6900     22.635
# 9/1/2010 2:00     15.8  1491.98000    3.6900     22.565
# 9/1/2010 3:00     15.8  1330.76000    3.6900     18.910
# 9/1/2010 4:00     15.8  1247.94000    3.6900     18.030
# ...                ...         ...       ...        ...
# 12/24/2010 16:00  33.3  1799.49565    3.0988     36.770
# 12/24/2010 17:00  33.3  1869.43815    3.0988     35.060
# 12/24/2010 18:00  33.3  1836.26230    3.0988     27.980
# 12/24/2010 19:00  33.3  1716.70845    3.0988     28.115
# 12/24/2010 20:00  33.3  1562.13960    3.0988     27.690
#
# [2757 rows x 4 columns]

# %%
#train_data

# %%
IElecData.tail(2757)
IElecDataT=IElecData.tail(2757)
IElecDataT
# Out:
#                  Tmax    SysLoad  GasPrice  ElecPrice
# FullDate
# 11/6/2020 3:00   18.2  676.84685    5.8000     55.320
# 11/6/2020 4:00   18.2  692.20005    5.8000     62.580
# 11/6/2020 5:00   18.2  673.36585    5.8000     67.685
# 11/6/2020 6:00   18.2  807.80015    5.8000     95.965
# 11/6/2020 7:00   18.2  907.90820    5.8000     72.345
# ...               ...        ...       ...        ...
# 2/28/2021 19:00  24.3  449.63625    5.4848    117.925
# 2/28/2021 20:00  24.3  815.59975    5.4848     87.880
# 2/28/2021 21:00  24.3  745.12325    5.4848     62.060
# 2/28/2021 22:00  24.3  694.95150    5.4848     62.000
# 2/28/2021 23:00  24.3  714.69630    5.4848     62.955
#
# [2757 rows x 4 columns]

# %%
#check for missing value

# %%
IElecData.isnull().sum()
# Out:
# Tmax         0
# SysLoad      0
# GasPrice     0
# ElecPrice    0
# dtype: int64

# %%
plt.xlabel( 'ElecPrice' ) 
plt.ylabel( 'FullDate' )
plt.plot(IElecDataH)
# Out:
# [<matplotlib.lines.Line2D at 0x29fbd2b0b20>,
#  <matplotlib.lines.Line2D at 0x29fbd2b0a30>,
#  <matplotlib.lines.Line2D at 0x29fbd2b0c70>,
#  <matplotlib.lines.Line2D at 0x29fbd2b0d30>]

# %%
ElecDataC
# Out:
#                  FullDate  Tmax     SysLoad  GasPrice  ElecPrice
# 0     2010-09-01 00:00:00  15.8  1688.21500    3.6900     23.710
# 1     2010-09-01 01:00:00  15.8  1669.19500    3.6900     22.635
# 2     2010-09-01 02:00:00  15.8  1491.98000    3.6900     22.565
# 3     2010-09-01 03:00:00  15.8  1330.76000    3.6900     18.910
# 4     2010-09-01 04:00:00  15.8  1247.94000    3.6900     18.030
# ...                   ...   ...         ...       ...        ...
# 92011 2021-02-28 19:00:00  24.3   449.63625    5.4848    117.925
# 92012 2021-02-28 20:00:00  24.3   815.59975    5.4848     87.880
# 92013 2021-02-28 21:00:00  24.3   745.12325    5.4848     62.060
# 92014 2021-02-28 22:00:00  24.3   694.95150    5.4848     62.000
# 92015 2021-02-28 23:00:00  24.3   714.69630    5.4848     62.955
#
# [92016 rows x 5 columns]

# %%
ElecDataC=ElecData.copy()
ElecDataC[ "FullDate" ] = pd.to_datetime(ElecDataC[ "FullDate" ])
ElecDataC.head(2757)
ElecDataCH=ElecDataC.head(2757)
ElecDataCH
# Out:
#                 FullDate  Tmax     SysLoad  GasPrice  ElecPrice
# 0    2010-09-01 00:00:00  15.8  1688.21500    3.6900     23.710
# 1    2010-09-01 01:00:00  15.8  1669.19500    3.6900     22.635
# 2    2010-09-01 02:00:00  15.8  1491.98000    3.6900     22.565
# 3    2010-09-01 03:00:00  15.8  1330.76000    3.6900     18.910
# 4    2010-09-01 04:00:00  15.8  1247.94000    3.6900     18.030
# ...                  ...   ...         ...       ...        ...
# 2752 2010-12-24 16:00:00  33.3  1799.49565    3.0988     36.770
# 2753 2010-12-24 17:00:00  33.3  1869.43815    3.0988     35.060
# 2754 2010-12-24 18:00:00  33.3  1836.26230    3.0988     27.980
# 2755 2010-12-24 19:00:00  33.3  1716.70845    3.0988     28.115
# 2756 2010-12-24 20:00:00  33.3  1562.13960    3.0988     27.690
#
# [2757 rows x 5 columns]

# %%
IElecDataC=ElecDataC.set_index(['FullDate'])
IElecDataCH=IElecDataC.head(2757)
#Train_Set
IElecDataCH
# Out:
#                      Tmax     SysLoad  GasPrice  ElecPrice
# FullDate
# 2010-09-01 00:00:00  15.8  1688.21500    3.6900     23.710
# 2010-09-01 01:00:00  15.8  1669.19500    3.6900     22.635
# 2010-09-01 02:00:00  15.8  1491.98000    3.6900     22.565
# 2010-09-01 03:00:00  15.8  1330.76000    3.6900     18.910
# 2010-09-01 04:00:00  15.8  1247.94000    3.6900     18.030
# ...                   ...         ...       ...        ...
# 2010-12-24 16:00:00  33.3  1799.49565    3.0988     36.770
# 2010-12-24 17:00:00  33.3  1869.43815    3.0988     35.060
# 2010-12-24 18:00:00  33.3  1836.26230    3.0988     27.980
# 2010-12-24 19:00:00  33.3  1716.70845    3.0988     28.115
# 2010-12-24 20:00:00  33.3  1562.13960    3.0988     27.690
#
# [2757 rows x 4 columns]

# %%
IElecDataCH.describe()
# Out:
#               Tmax      SysLoad     GasPrice    ElecPrice
# count  2757.000000  2757.000000  2757.000000  2757.000000
# mean     21.861480  1405.987182     2.763018    22.115350
# std       5.553883   339.155392     0.838737   100.359592
# min      13.600000   100.089000     0.000000  -912.810000
# 25%      18.000000  1223.875000     2.397800    17.925000
# 50%      20.800000  1430.465000     2.713900    21.050000
# 75%      25.100000  1637.010000     3.310000    25.145000
# max      38.200000  2632.265000     4.769900  4303.245000

# %%
#Test_Set
IElecDataCT=IElecDataC.tail(2757)
IElecDataCT
# Out:
#                      Tmax    SysLoad  GasPrice  ElecPrice
# FullDate
# 2020-11-06 03:00:00  18.2  676.84685    5.8000     55.320
# 2020-11-06 04:00:00  18.2  692.20005    5.8000     62.580
# 2020-11-06 05:00:00  18.2  673.36585    5.8000     67.685
# 2020-11-06 06:00:00  18.2  807.80015    5.8000     95.965
# 2020-11-06 07:00:00  18.2  907.90820    5.8000     72.345
# ...                   ...        ...       ...        ...
# 2021-02-28 19:00:00  24.3  449.63625    5.4848    117.925
# 2021-02-28 20:00:00  24.3  815.59975    5.4848     87.880
# 2021-02-28 21:00:00  24.3  745.12325    5.4848     62.060
# 2021-02-28 22:00:00  24.3  694.95150    5.4848     62.000
# 2021-02-28 23:00:00  24.3  714.69630    5.4848     62.955
#
# [2757 rows x 4 columns]

# %%
IElecDataCT.describe()
# Out:
#               Tmax      SysLoad     GasPrice    ElecPrice
# count  2757.000000  2757.000000  2757.000000  2757.000000
# mean     26.993036    43.093297     6.191719    25.637575
# std       5.544121   687.014520     0.534033    73.907927
# min      18.200000 -1596.810100     4.466000  -500.655000
# 25%      22.400000  -487.180450     5.787800     9.235000
# 50%      25.700000    66.152700     6.220000    33.450000
# 75%      31.000000   556.931450     6.600000    45.650000
# max      42.000000  2261.228750     7.400000  2537.470000

# %%
ElecDataCH['Year']=ElecDataCH['FullDate'].apply(lambda x: str(x)[-4:])
ElecDataCH['Month']=ElecDataCH['FullDate'].apply(lambda x: str(x)[-6:-4])
ElecDataCH['Day']=ElecDataCH['FullDate'].apply(lambda x: str(x)[:-6])
ElecDataCH['ds']=pd.DatetimeIndex(ElecDataCH['Year']+'-'+ElecDataCH['Month']+'-'+ElecDataCH['Day'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Documents\New folder\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1857         try:
# -> 1858             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1859             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-48-b0f6464be0a6> in <module>
#       2 ElecDataCH['Month']=ElecDataCH['FullDate'].apply(lambda x: str(x)[-6:-4])
#       3 ElecDataCH['Day']=ElecDataCH['FullDate'].apply(lambda x: str(x)[:-6])
# ----> 4 ElecDataCH['ds']=pd.DatetimeIndex(ElecDataCH['Year']+'-'+ElecDataCH['Month']+'-'+ElecDataCH['Day'])
#
# ~\Documents\New folder\lib\site-packages\pandas\core\indexes\datetimes.py in __new__(cls, data, freq, tz, normalize, closed, ambiguous, dayfirst, yearfirst, dtype, copy, name)
#     243         name = maybe_extract_name(name, data, cls)
#     244
# --> 245         dtarr = DatetimeArray._from_sequence(
#     246             data,
#     247             dtype=dtype,
#
# ~\Documents\New folder\lib\site-packages\pandas\core\arrays\datetimes.py in _from_sequence(cls, data, dtype, copy, tz, freq, dayfirst, yearfirst, ambiguous)
#     311         freq, freq_infer = dtl.maybe_infer_freq(freq)
#     312
# --> 313         subarr, tz, inferred_freq = sequence_to_dt64ns(
#     314             data,
#     315             dtype=dtype,
#
# ~\Documents\New folder\lib\site-packages\pandas\core\arrays\datetimes.py in sequence_to_dt64ns(data, dtype, copy, tz, dayfirst, yearfirst, ambiguous)
#    1752             # data comes back here as either i8 to denote UTC timestamps
#    1753             #  or M8[ns] to denote wall times
# -> 1754             data, inferred_tz = objects_to_datetime64ns(
#    1755                 data, dayfirst=dayfirst, yearfirst=yearfirst
#    1756             )
#
# ~\Documents\New folder\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1861             return values.view("i8"), tz_parsed
#    1862         except (ValueError, TypeError):
# -> 1863             raise e
#    1864
#    1865     if tz_parsed is not None:
#
# ~\Documents\New folder\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1846
#    1847     try:
# -> 1848         result, tz_parsed = tslib.array_to_datetime(
#    1849             data,
#    1850             errors=errors,
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\Documents\New folder\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1372         return parser(parserinfo).parse(timestr, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#    1376
#
# ~\Documents\New folder\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647
#     648         if res is None:
# --> 649             raise ParserError("Unknown string format: %s", timestr)
#     650
#     651         if len(res) == 0:
#
# ParserError: Unknown string format: 0:00-:0-2010-09-01 00

# %%
print(IElecDataCH['ElecPrice'].unique())
print(IElecDataCH['SysLoad'].unique())
# Out:
# [23.71  22.635 22.565 ... 27.98  28.115 27.69 ]
# [1688.215   1669.195   1491.98    ... 1836.2623  1716.70845 1562.1396 ]

# %%
plt.xlabel( 'FullDate' ) 
plt.ylabel( 'ElecPrice' )
plt.plot(IElecDataCH)
# Out:
# [<matplotlib.lines.Line2D at 0x29fc02e0130>,
#  <matplotlib.lines.Line2D at 0x29fc0321490>,
#  <matplotlib.lines.Line2D at 0x29fc0321e50>,
#  <matplotlib.lines.Line2D at 0x29fc0321310>]

# %%
plt.xlabel( 'FullDate' ) 
plt.ylabel( 'ElecPrice' )
plt.plot(IElecDataCT)
# Out:
# [<matplotlib.lines.Line2D at 0x29fc039f9d0>,
#  <matplotlib.lines.Line2D at 0x29fc00bbd00>,
#  <matplotlib.lines.Line2D at 0x29fc00bb790>,
#  <matplotlib.lines.Line2D at 0x29fc00bb610>]

# %%
#Estimating Trend
IElecDataCH_Log=np.log(IElecDataCH)
plt.plot(IElecDataCH_Log)
# Out:
# <ipython-input-21-67008f8c51d0>:2: RuntimeWarning: divide by zero encountered in log
#   IElecDataCH_Log=np.log(IElecDataCH)
# <ipython-input-21-67008f8c51d0>:2: RuntimeWarning: invalid value encountered in log
#   IElecDataCH_Log=np.log(IElecDataCH)
# [<matplotlib.lines.Line2D at 0x29fc02cbf40>,
#  <matplotlib.lines.Line2D at 0x29fc04405e0>,
#  <matplotlib.lines.Line2D at 0x29fc04396a0>,
#  <matplotlib.lines.Line2D at 0x29fc0439490>]

# %%
IElecDataCT_Log=np.log(IElecDataCT)
plt.plot(IElecDataCT_Log)
# Out:
# <ipython-input-22-fcc993875dfc>:1: RuntimeWarning: divide by zero encountered in log
#   IElecDataCT_Log=np.log(IElecDataCT)
# <ipython-input-22-fcc993875dfc>:1: RuntimeWarning: invalid value encountered in log
#   IElecDataCT_Log=np.log(IElecDataCT)
# [<matplotlib.lines.Line2D at 0x29fc02c07f0>,
#  <matplotlib.lines.Line2D at 0x29fc1a49670>,
#  <matplotlib.lines.Line2D at 0x29fc1a495b0>,
#  <matplotlib.lines.Line2D at 0x29fc1a49490>]

# %%
IElecDataC_Log=np.log(IElecDataC)
plt.plot(IElecDataC_Log)
# Out:
# <ipython-input-23-f6e71402792b>:1: RuntimeWarning: divide by zero encountered in log
#   IElecDataC_Log=np.log(IElecDataC)
# <ipython-input-23-f6e71402792b>:1: RuntimeWarning: invalid value encountered in log
#   IElecDataC_Log=np.log(IElecDataC)
# [<matplotlib.lines.Line2D at 0x29fc1a6d160>,
#  <matplotlib.lines.Line2D at 0x29fc23eec40>,
#  <matplotlib.lines.Line2D at 0x29fc23eeb80>,
#  <matplotlib.lines.Line2D at 0x29fc23eea60>]

# %%
IElecDataCMA = IElecDataCH_Log[ 'ElecPrice' ].rolling( 12 ).mean()
print(IElecDataCMA)
plt.plot(IElecDataCMA)
plt.plot(IElecDataCMA, color='green')
# Out:
# FullDate
# 2010-09-01 00:00:00         NaN
# 2010-09-01 01:00:00         NaN
# 2010-09-01 02:00:00         NaN
# 2010-09-01 03:00:00         NaN
# 2010-09-01 04:00:00         NaN
#                          ...
# 2010-12-24 16:00:00    3.038162
# 2010-12-24 17:00:00    3.142743
# 2010-12-24 18:00:00    3.224261
# 2010-12-24 19:00:00    3.285210
# 2010-12-24 20:00:00    3.359678
# Name: ElecPrice, Length: 2757, dtype: float64

# %%
IElecDataCMA = IElecDataC_Log[ 'ElecPrice' ].rolling( 12 ).mean()
print(IElecDataCMA)
plt.plot(IElecDataCMA)
plt.plot(IElecDataCMA, color='red')
# Out:
# FullDate
# 2010-09-01 00:00:00   NaN
# 2010-09-01 01:00:00   NaN
# 2010-09-01 02:00:00   NaN
# 2010-09-01 03:00:00   NaN
# 2010-09-01 04:00:00   NaN
#                        ..
# 2021-02-28 19:00:00   NaN
# 2021-02-28 20:00:00   NaN
# 2021-02-28 21:00:00   NaN
# 2021-02-28 22:00:00   NaN
# 2021-02-28 23:00:00   NaN
# Name: ElecPrice, Length: 92016, dtype: float64

# %%
IElecDataCMA = IElecDataCT_Log[ 'ElecPrice' ].rolling( 12 ).mean()
print(IElecDataCMA)
plt.plot(IElecDataCMA)
plt.plot(IElecDataCMA, color='blue')
# Out:
# FullDate
# 2020-11-06 03:00:00   NaN
# 2020-11-06 04:00:00   NaN
# 2020-11-06 05:00:00   NaN
# 2020-11-06 06:00:00   NaN
# 2020-11-06 07:00:00   NaN
#                        ..
# 2021-02-28 19:00:00   NaN
# 2021-02-28 20:00:00   NaN
# 2021-02-28 21:00:00   NaN
# 2021-02-28 22:00:00   NaN
# 2021-02-28 23:00:00   NaN
# Name: ElecPrice, Length: 2757, dtype: float64

# %%
import statsmodels.api as sm 
from matplotlib.pylab import rcParams 
rcParams[ 'figure.figsize' ] = 15 , 8 
decompose_IElecDataC = sm.tsa.seasonal_decompose(IElecDataC[ 'ElecPrice' ], model= 'additive' ) 
decompose_IElecDataC.plot() 
plt.show()

# %%
import statsmodels.api as sm 
from matplotlib.pylab import rcParams 
rcParams[ 'figure.figsize' ] = 15 , 8 
decompose_IElecDataCH = sm.tsa.seasonal_decompose(IElecDataCH[ 'ElecPrice' ], model= 'additive' ) 
decompose_IElecDataCH.plot() 
plt.show()

# %%
import statsmodels.api as sm 
from matplotlib.pylab import rcParams 
rcParams[ 'figure.figsize' ] = 15 , 8 
decompose_IElecDataCT = sm.tsa.seasonal_decompose(IElecDataCT[ 'ElecPrice' ], model= 'additive' ) 
decompose_IElecDataCT.plot() 
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
adf_result = adfuller(IElecDataC[ 'ElecPrice' ]) 
print( f'ADF Statistic: {adf_result[ 0 ]} ' ) 
print( f'p-value: {adf_result[ 0:4 ]} ' ) 
print( f'No. of lags used: {adf_result[ 2 ]} ' ) 
print( f'No. of observations used : {adf_result[ 3 ]} ' ) 
print( 'Critical Values:' ) 
for k, v in adf_result[ 4 ].items(): 
 print( f' {k} : {v} ' )
# Out:
# ADF Statistic: -31.95297569955787
# p-value: (-31.95297569955787, 0.0, 53, 91962)
# No. of lags used: 53
# No. of observations used : 91962
# Critical Values:
#  1% : -3.430421110703783
#  5% : -2.8615714297867108
#  10% : -2.56678672898094

# %%
from statsmodels.tsa.stattools import adfuller
adf_result = adfuller(IElecDataCH[ 'ElecPrice' ]) 
print( f'ADF Statistic: {adf_result[ 0 ]} ' ) 
print( f'p-value: {adf_result[ 1 ]} ' ) 
print( f'No. of lags used: {adf_result[ 2 ]} ' ) 
print( f'No. of observations used : {adf_result[ 3 ]} ' ) 
print( 'Critical Values:' ) 
for k, v in adf_result[ 4 ].items(): 
 print( f' {k} : {v} ' )
# Out:
# ADF Statistic: -28.03740891587019
# p-value: 0.0
# No. of lags used: 2
# No. of observations used : 2754
# Critical Values:
#  1% : -3.4327266904892513
#  5% : -2.862590051808033
#  10% : -2.5673289760243105

# %%
from statsmodels.tsa.stattools import acf, pacf 
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 
 
lag_acf=acf(IElecDataCH_Log['ElecPrice'], nlags=20)
lag_pacf=pacf(IElecDataCH_Log['ElecPrice'], nlags=20)
#ACF
plt.plot(lag_acf)
#PACF
plt.plot(lag_pacf)
# Out:
# C:\Users\OVC 2\Documents\New folder\lib\site-packages\statsmodels\tsa\stattools.py:568: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(

# %%
#PACF 
plot_pacf(IEDCH_diff, lags = range( 0 , 20 )) 
plt.show()

# %%
IEDCH_log = np.log(IElecDataCH) 
IEDCH_diff = IEDCH_log.diff(periods= 1 ) 
plt.plot(IEDCH_diff.index, IEDCH_diff.ElecPrice, '-' ) 
plt.plot(IEDCH_diff.rolling( 12 ).mean(), color= 'red' )

# %%
import warnings;
warnings.simplefilter('ignore')

# %%
# !pip install pystan fbprophet
# Out:
# Collecting pystan
#   Using cached pystan-3.4.0-py3-none-any.whl (13 kB)
# Collecting fbprophet
#   Using cached fbprophet-0.7.1.tar.gz (64 kB)
# Collecting numpy<2.0,>=1.19
#   Downloading numpy-1.22.3-cp38-cp38-win_amd64.whl (14.7 MB)
# Collecting pysimdjson<4.0,>=3.2
#   Using cached pysimdjson-3.2.0-cp38-cp38-win_amd64.whl (151 kB)
# Collecting clikit<0.7,>=0.6
#   Using cached clikit-0.6.2-py2.py3-none-any.whl (91 kB)
# Requirement already satisfied: setuptools in c:\users\ovc 2\documents\new folder\lib\site-packages (from pystan) (49.2.0.post20200714)
# ERROR: Could not find a version that satisfies the requirement httpstan<4.8,>=4.7 (from pystan) (from versions: 0.2.5, 0.3.0, 0.3.1, 0.4.0, 0.5.0, 0.6.0, 0.7.2, 0.7.3, 0.7.5, 0.7.6, 0.8.0, 0.9.0, 0.10.1)
# ERROR: No matching distribution found for httpstan<4.8,>=4.7 (from pystan)

# %%
#importing facebook prophet

from prophet import Prophet
IEDCH_model = Prophet() 
IEDCH_model.fit(IElecDataCH)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-35-2635e11352b5> in <module>
#       1 #importing facebook prophet
#       2
# ----> 3 from prophet import Prophet
#       4 IEDCH_model = Prophet()
#       5 IEDCH_model.fit(IElecDataCH)
#
# ModuleNotFoundError: No module named 'prophet'
